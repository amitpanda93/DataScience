# %%
import pandas as pd

# %%
data= pd.read_excel('Data_Train.xlsx')
data.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am – 1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am – 1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
data[data.duplicated()].shape
# Out:
# (25, 9)

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (12665, 9)

# %%
data.CUISINES = data.CUISINES.apply(lambda x: x.split(','))

# %%
data.CUISINES
# Out:
# 0                          [Malwani,  Goan,  North Indian]
# 1                       [Asian,  Modern Indian,  Japanese]
# 2          [North Indian,  Chinese,  Biryani,  Hyderabadi]
# 3                                      [Tibetan,  Chinese]
# 4                                               [Desserts]
# 5             [North Indian,  Chinese,  Seafood,  Biryani]
# 6         [Cafe,  Chinese,  Pizza,  North Indian,  Burger]
# 7                                               [Bar Food]
# 8                            [South Indian,  North Indian]
# 9                                           [North Indian]
# 10          [North Indian,  Chinese,  Fast Food,  Biryani]
# 11                        [Fast Food,  Burger,  Beverages]
# 12                                     [Arabian,  Mughlai]
# 13                                          [South Indian]
# 14                                         [Maharashtrian]
# 15                                    [Parsi,  Hyderabadi]
# ...

# %%
cuisine_list = []
dictionary = {}
max = 0
for x in data.CUISINES.values:
    count = 0
    for y in x:
        count = count+1
        if y.strip() in cuisine_list:
            cuisine_list.append(y.strip())
    if count>max:
        max = count

print(max)
# Out:
# 8

# %%
cuisine_list.sort()
cuisine_list
# Out:
# ['',
#  'Afghan',
#  'African',
#  'American',
#  'Andhra',
#  'Arabian',
#  'Armenian',
#  'Asian',
#  'Assamese',
#  'Awadhi',
#  'BBQ',
#  'Bakery',
#  'Bar Food',
#  'Belgian',
#  'Bengali',
#  'Beverages',
#  'Bihari',
#  'Biryani',
#  'Bohri',
#  'British',
#  'Bubble Tea',
#  'Burger',
#  'Burmese',
#  'Cafe',
#  'Cafe Food',
#  'Cantonese',
#  'Charcoal Chicken',
#  'Chettinad',
#  'Chinese',
#  'Coffee',
#  'Coffee and Tea',
#  'Continental',
#  'Cuisine Varies',
#  'Desserts',
#  'Drinks Only',
#  'Dumplings',
#  'Egyptian',
#  'Ethiopian',
#  'European',
#  'Fast Food',
#  'Finger Food',
#  'French',
#  'Fusion',
#  'German',
#  'Goan',
#  'Greek',
#  'Grill',
#  'Gujarati',
#  'Healthy Food',
#  'Hot Pot',
#  'Hot dogs',
#  'Hyderabadi',
#  'Ice Cream',
#  'Indian',
#  'Indonesian',
#  'Iranian',
#  'Irish',
#  'Italian',
#  'Japanese',
#  'Jewish',
#  'Juices',
#  'Kashmiri',
#  'Kebab',
#  'Kerala',
#  'Konkan',
#  'Korean',
#  'Lebanese',
#  'Lucknowi',
# ...

# %%
data.TIME.value_counts()
# Out:
# 11am – 11pm (Mon-Sun)                                   1414
# 12noon – 12midnight (Mon-Sun)                            468
# 12noon – 11pm (Mon-Sun)                                  405
# 11am – 12midnight (Mon-Sun)                              309
# 10am – 10pm (Mon-Sun)                                    221
# 12noon – 1am (Mon-Sun)                                   197
# 10am – 11pm (Mon-Sun)                                    183
# 7am – 11pm (Mon-Sun)                                     182
# 8am – 11pm (Mon-Sun)                                     175
# 24 Hours (Mon-Sun)                                       172
# 12noon – 11:30pm (Mon-Sun)                               156
# 11am – 10pm (Mon-Sun)                                    154
# 11am – 11:30pm (Mon-Sun)                                 143
# 11:30am – 11:30pm (Mon-Sun)                              138
# 9am – 11pm (Mon-Sun)                                     120
# ...
